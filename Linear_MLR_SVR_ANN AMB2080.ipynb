# %%
HARI PAVAN YADAV G AMB2080

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("heart_data.csv")
print(df.head())
# Out:
#    Unnamed: 0     biking    smoking  heart_disease
# 0           1  30.801246  10.896608      11.769423
# 1           2  65.129215   2.219563       2.854081
# 2           3   1.959665  17.588331      17.177803
# 3           4  44.800196   2.802559       6.816647
# 4           5  69.428454  15.974505       4.062224

# %%
#simple Linear Regression
X = df[['biking']]     # single independent variable
y = df['heart_disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)

y_predHD=model.predict([[30.8]])
print(y_predHD)

y_predHD=model.predict(X_test)
print("Predicted:", y_predHD[0:5])
print("Actual:", y_test.values[0:5])
# Out:
# Intercept: 17.684117107486635
# Coefficients: [-0.19764301]
# [11.59671252]
# Predicted: [ 4.7974545  13.96620946  6.47273614  7.89543221 10.55192816]
# Actual: [ 7.18494637 15.08736023  6.73577092  8.02740434  9.7315448 ]
# c:\Users\pranav\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import metrics
import numpy as np

# Error calculations
print("MAE:", metrics.mean_absolute_error(y_test, y_predHD))
print("MSE:", metrics.mean_squared_error(y_test, y_predHD))
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_predHD)))
print("R2 Score:", metrics.r2_score(y_test, y_predHD))
# Out:
# MAE: 1.359865544030561
# MSE: 2.7502458738355977
# RMSE: 1.6583865272714915
# R2 Score: 0.8665983993707086

# %%
#to avoid warning
new_pred = model.predict(pd.DataFrame([[30.8]], columns=['biking']))
print(new_pred)
# Out:
# [11.59671252]

# %%
Follow these steps to perform the calculation:

Identify the explanatory variables you plan to use for the regression analysis.
Collect data on these variables along with the response variable.
Use statistical software to input the data and perform the regression analysis.
Analyze the output to understand the relationships between variables.
Interpret the coefficients to assess the impact of each explanatory variable on the response variable.

# %%
#Multiple Linear Regression
X = df[['biking', 'smoking']]
y = df['heart_disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)

y_predHD=model.predict([[30.8,10.9]])
print(y_predHD)

y_predHD=model.predict(X_test)
print("Predicted:", y_predHD[0:5])
print("Actual:", y_test.values[0:5])

# Error calculations
print("MAE:", metrics.mean_absolute_error(y_test, y_predHD))
print("MSE:", metrics.mean_squared_error(y_test, y_predHD))
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_predHD)))
print("R2 Score:", metrics.r2_score(y_test, y_predHD))
# Out:
# Intercept: 14.970857254018798
# Coefficients: [-0.20004699  0.17852649]
# [10.75534868]
# Predicted: [17.78368326 14.62451134 12.9802823  18.55713596 16.78343221]
# Actual: [17.41181092 13.52507124 13.19170331 18.48295977 17.35457709]
# MAE: 0.4994551868804127
# MSE: 0.37735257976225883
# RMSE: 0.6142903057693967
# R2 Score: 0.9831483905131839
# c:\Users\pranav\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Multiple Linear Regression
from sklearn.svm import SVR
X = df[['biking', 'smoking']]
y = df['heart_disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = SVR(kernel='rbf')
#model = SVR(kernel='linear')
model.fit(X_train, y_train)

print("Intercept:", model.intercept_)
#print("Coefficients:", model.coef_)  #coef_ is only available when using a linear kernel

y_predHD=model.predict(X_test)
print("Predicted:", y_predHD[0:5])
print("Actual:", y_test.values[0:5])

# Error calculations
print("MAE:", metrics.mean_absolute_error(y_test, y_predHD))
print("MSE:", metrics.mean_squared_error(y_test, y_predHD))
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_predHD)))
print("R2 Score:", metrics.r2_score(y_test, y_predHD))
# Out:
# Intercept: [10.0859002]
# Predicted: [13.91663757 12.06489334  8.8983195   8.23571027 11.95760534]
# Actual: [14.41148296 12.09848437  9.54365568  7.25794619 11.66476484]
# MAE: 0.4796163826701409
# MSE: 0.3897167620532382
# RMSE: 0.6242729868040409
# R2 Score: 0.9782071130904751

# %%
#Artificail Neural Network
from sklearn.neural_network import MLPRegressor

X = df[['biking', 'smoking']]
y = df['heart_disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = MLPRegressor(hidden_layer_sizes=(6,6), max_iter=500)  
#Two hidden layers with 6 neurons each
#Number of training iterations
model.fit(X_train, y_train)


y_predHD=model.predict(X_test)
print("Predicted:", y_predHD[0:5])
print("Actual:", y_test.values[0:5])

# Error calculations
print("MAE:", metrics.mean_absolute_error(y_test, y_predHD))
print("MSE:", metrics.mean_squared_error(y_test, y_predHD))
print("RMSE:", np.sqrt(metrics.mean_squared_error(y_test, y_predHD)))
print("R2 Score:", metrics.r2_score(y_test, y_predHD))
# Out:
# Predicted: [15.95741252  9.77218679  7.02561537  4.88579274  9.19283037]
# Actual: [15.99298644 13.41654743  6.66207532  5.52393102  7.57261423]
# MAE: 1.98729363559888
# MSE: 6.055061249249236
# RMSE: 2.460703405380103
# R2 Score: 0.7381469253334303
# c:\Users\pranav\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
