# %% [markdown]
# HARI PAVAN YADAV G AMB2080

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/agri_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5491/4183279021.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/content/drive/MyDrive/agri_data.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df=pd.read_csv("agri_data.csv")

# %%
df
# Out:
#    Year Region   Crop  Area_Hectares  Production_Tons  Rainfall_mm  \
# 0  2018  North  Wheat           1200             3600          800
# 1  2018  South   Rice           1500             5000         1200
# 2  2019  North  Wheat           1250             3700          820
# 3  2019  South   Rice           1600             5200         1150
# 4  2020  North  Wheat           1300             3900          780
# 5  2020  South   Rice           1700             5400         1300
# 6  2021  North  Wheat           1280             4000          900
# 7  2021  South   Rice           1750             5600         1250
# 8  2022  North  Wheat           1350             4200          850
# 9  2022  South   Rice           1800             6000         1400
#
#    Temperature_C
# 0             22
# 1             28
# 2             23
# 3             29
# 4             24
# 5             30
# 6             23
# 7             31
# 8             25
# 9             32

# %%
print(df)
# Out:
#    Year Region   Crop  Area_Hectares  Production_Tons  Rainfall_mm  \
# 0  2018  North  Wheat           1200             3600          800
# 1  2018  South   Rice           1500             5000         1200
# 2  2019  North  Wheat           1250             3700          820
# 3  2019  South   Rice           1600             5200         1150
# 4  2020  North  Wheat           1300             3900          780
# 5  2020  South   Rice           1700             5400         1300
# 6  2021  North  Wheat           1280             4000          900
# 7  2021  South   Rice           1750             5600         1250
# 8  2022  North  Wheat           1350             4200          850
# 9  2022  South   Rice           1800             6000         1400
#
#    Temperature_C
# 0             22
# 1             28
# 2             23
# 3             29
# 4             24
# 5             30
# 6             23
# 7             31
# 8             25
# 9             32

# %%
print("total rows:",len(df))
print("total columns:",len(df))
# Out:
# total rows: 10
# total columns: 10

# %%
#show first 5 rows
print("first 5 rows:")
print(df.head())
# Out:
# first 5 rows:
#    Year Region   Crop  Area_Hectares  Production_Tons  Rainfall_mm  \
# 0  2018  North  Wheat           1200             3600          800
# 1  2018  South   Rice           1500             5000         1200
# 2  2019  North  Wheat           1250             3700          820
# 3  2019  South   Rice           1600             5200         1150
# 4  2020  North  Wheat           1300             3900          780
#
#    Temperature_C
# 0             22
# 1             28
# 2             23
# 3             29
# 4             24

# %%
#basic info
print("basic info:")
print(df.info())
# Out:
# basic info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10 non-null     int64
#  1   Region           10 non-null     object
#  2   Crop             10 non-null     object
#  3   Area_Hectares    10 non-null     int64
#  4   Production_Tons  10 non-null     int64
#  5   Rainfall_mm      10 non-null     int64
#  6   Temperature_C    10 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 692.0+ bytes
# None

# %%
#summary stastics
print("\n summary statistics:")
print(df.describe())
# Out:
#  summary statistics:
#               Year  Area_Hectares  Production_Tons  Rainfall_mm  Temperature_C
# count    10.000000      10.000000        10.000000    10.000000      10.000000
# mean   2020.000000    1473.000000      4660.000000  1045.000000      26.700000
# std       1.490712     225.735834       875.848795   237.592087       3.713339
# min    2018.000000    1200.000000      3600.000000   780.000000      22.000000
# 25%    2019.000000    1285.000000      3925.000000   827.500000      23.250000
# 50%    2020.000000    1425.000000      4600.000000  1025.000000      26.500000
# 75%    2021.000000    1675.000000      5350.000000  1237.500000      29.750000
# max    2022.000000    1800.000000      6000.000000  1400.000000      32.000000

# %%
df["Rainfall_mm"]
# Out:
# 0     800
# 1    1200
# 2     820
# 3    1150
# 4     780
# 5    1300
# 6     900
# 7    1250
# 8     850
# 9    1400
# Name: Rainfall_mm, dtype: int64

# %% [markdown]
# df("Crop")

# %%
#filter data (only wheat)
Wheat_data=df[df["Crop"]=="Wheat"]
print("\n Wheat data:")
print(Wheat_data)
# Out:
#  Wheat data:
#    Year Region   Crop  Area_Hectares  Production_Tons  Rainfall_mm  \
# 0  2018  North  Wheat           1200             3600          800
# 2  2019  North  Wheat           1250             3700          820
# 4  2020  North  Wheat           1300             3900          780
# 6  2021  North  Wheat           1280             4000          900
# 8  2022  North  Wheat           1350             4200          850
#
#    Temperature_C
# 0             22
# 2             23
# 4             24
# 6             23
# 8             25

# %%
#group by year and sum production
yearly_production=df.groupby("Year")["Production_Tons"].sum()
print("\n Yearly Total Production:")
print(yearly_production)
# Out:
#  Yearly Total Production:
# Year
# 2018     8600
# 2019     8900
# 2020     9300
# 2021     9600
# 2022    10200
# Name: Production_Tons, dtype: int64

# %%
#create bar plot
plt.figure(figsize=(10,6))
plt.bar(yearly_production.index,yearly_production.values,color='skyblue')
plt.xlabel("year")
plt.ylabel("Total Production(Tons)")
plt.title("Total Crop Production Per Year")
plt.xticks()
plt.show()

# %%
#scatter plot-Rainfall vs production
import matplotlib.pyplot as plt
plt.scatter(df["Rainfall_mm"],df["Production_Tons"])
plt.xlabel("Rainfall(mm)")
plt.ylabel("Production(Tons)")
plt.title("Rainfall vs Production")
plt.show()

# %%
#line plot: production
#filter data for each crop
wheat=df[df["Crop"]=="Wheat"]
rice=df[df["Crop"]=="Rice"]

plt.figure()
#plot separately
plt.plot(wheat["Year"],wheat["Production_Tons"],label="wheat")
plt.plot(rice["Year"],rice["Production_Tons"],label="Rice")
plt.xlabel("Year")
plt.ylabel("Production(Tons)")
plt.title("Crop Production Over Time")
plt.legend()
plt.show()

# %%
#custom styled bar plot
plt.figure(figsize=(8,5))
bars=plt.bar(yearly_production)
for bar in bars
height=bar.get_height()
plt.text(bar.get_x()+bar.get_width()/2,
         height,
         str(height),
         ha='center',
         va='bottom')
plt.xlabel("Year")
plt.ylabel("Total Production(Tons)")
plt.title("Total Crop Production Per Year")
plt.show()
# Out:
#   File "/tmp/ipython-input-3766066684.py", line 4
#     for bar in bars
#                    ^
# SyntaxError: expected ':'

# %% [markdown]
# 15-02-2026

# %%
import pandas as pd
import numpy as np

# create data with missing values

data=pd.DataFrame({
    'plot':['A','B','C','D','E'],
    'yield_kg':[2500,np.nan,2800,np.nan,2600],
    'rainfall':[150,200,np.nan,180,170],
    'temperature':[25,30,29,np.nan,27]
})
print("===data with missing values===")
print(data)

#===detecting missing data===
print("\n=== detecting missing values===")
print('Is null?')
print(data.isnull())
print(f"\n total missing per column:")
print(data.isnull().sum())
# Out:
# ===data with missing values===
#   plot  yield_kg  rainfall  temperature
# 0    A    2500.0     150.0         25.0
# 1    B       NaN     200.0         30.0
# 2    C    2800.0       NaN         29.0
# 3    D       NaN     180.0          NaN
# 4    E    2600.0     170.0         27.0
#
# === detecting missing values===
# Is null?
#     plot  yield_kg  rainfall  temperature
# 0  False     False     False        False
# 1  False      True     False        False
# 2  False     False      True        False
# 3  False      True     False         True
# 4  False     False     False        False
#
#  total missing per column:
# plot           0
# yield_kg       2
# rainfall       1
# temperature    1
# dtype: int64

# %%
#===FILLING MISSING VALUES===
print("\n=== Filling strategics===")
#fill with mean
data_mean=data.copy()
print(data_mean['yeild_kg'])
data_mean['yield_kg']=data_mean['yield_kg'].fillna(data_mean['yield_kg'].mean())
print('\n',"fill with mean:")
print(data_mean['yield_kg'])
# Out:
# === Filling strategics===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-564157703.py in <cell line: 0>()
#       2 print("\n=== Filling strategics===")
#       3 #fill with mean
# ----> 4 data_mean=data.copy()
#       5 print(data_mean['yeild_kg'])
#       6 data_mean['yield_kg']=data_mean['yield_kg'].fillna(data_mean['yield_kg'].mean())
#
# NameError: name 'data' is not defined

# %%
#fill with median
data_median=data.copy()
print(data_median['rainfall'])
data_median['rainfall']=data_median["rainfall"].fillna(data_median['rainfall'].median())
print(data_median['rainfall'])
print('\n',"fill with median:")
print(data_median)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3460746839.py in <cell line: 0>()
#       1 #fill with median
# ----> 2 data_median=data.copy()
#       3 print(data_median['rainfall'])
#       4 data_median['rainfall']=data_median["rainfall"].fillna(data_median['rainfall'].median())
#       5 print(data_median['rainfall'])
#
# NameError: name 'data' is not defined

# %%
#forward fill(use previous value)
data_ffill=data.copy()
print(data_ffill)
data_ffill=data_ffill.fillna(method='ffill')
print('\nForward fill:')
print(data_ffill)
#ffill-it replaces missing values(NaN)
#with the last valid(non-missing) value above it in column
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3494884373.py in <cell line: 0>()
#       1 #forward fill(use previous value)
# ----> 2 data_ffill=data.copy()
#       3 print(data_ffill)
#       4 data_ffill=data_ffill.fillna(method='ffill')
#       5 print('\nForward fill:')
#
# NameError: name 'data' is not defined

# %%
#===dropping missing data===
print("\n=== Dropping Rows ===")
data_dropped=data.dropna()
print(data_dropped)
print(f"original rows: {len(data)},after drop:{len(data_dropped)}")
# Out:
# === Dropping Rows ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1114332515.py in <cell line: 0>()
#       1 #===dropping missing data===
#       2 print("\n=== Dropping Rows ===")
# ----> 3 data_dropped=data.dropna()
#       4 print(data_dropped)
#       5 print(f"original rows: {len(data)},after drop:{len(data_dropped)}")
#
# NameError: name 'data' is not defined

# %% [markdown]
# 18-02-2026

# %%
# impoting the necessary packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Salary_Data.csv')
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
#slice the dataset as descriptive
#target variable

x=dataset.iloc[:,0].values
y=dataset.iloc[:,-1].values
print(x)
print(y)
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
print(dataset.shape)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (30, 2)
# (20,)
# (10,)
# (20,)
# (10,)

# %% [markdown]
# 19-02-2026
