# %% [markdown]
# HARI PAVAN YADAV AMB2080

# %%
import pandas as pd

production=pd.Series(
    [30,60,45,25],
    index=["Wheat","Rice","Maize","Barley"]
)
print(production)
# Out:
# Wheat     30
# Rice      60
# Maize     45
# Barley    25
# dtype: int64

# %%
#by crop name
print(production["Rice"])
print(production.loc["Rice"])
# Out:
# 60
# 60

# %%
#by position
print(production.iloc[0])
# Out:
# 30

# %%
print(production.sum())
print(production.mean())
print(production.max())
print(production.min())
print(production.idxmax())  #maixmum production crop
#it prints the index label of the maximum value in the series
# Out:
# 160
# 40.0
# 60
# 25
# Rice

# %%
import pandas as pd

production=pd.Series(
    [30,60,45,25],
    index=["Wheat","Rice","Maize","Barley"]
)

#crops with the production greater than 40 tons
high_production=production[production>40]
print(high_production)
print()
# Out:
# Rice     60
# Maize    45
# dtype: int64

# %%
import pandas as pd
df=pd.DataFrame({
    "name":["Akhil","Bobby","Charan"],
    "age":[25,30,35],
    "city":["NY","LS","chicago"],
},index=["a","b","c"])
print(df)
print()
print(df.loc["b"])
# Out:
#      name  age     city
# a   Akhil   25       NY
# b   Bobby   30       LS
# c  Charan   35  chicago
#
# name    Bobby
# age        30
# city       LS
# Name: b, dtype: object

# %%
print(df)
print()
print(df.loc[["a","c"],["name","city"]])
# Out:
#      name  age     city
# a   Akhil   25       NY
# b   Bobby   30       LS
# c  Charan   35  chicago
#
#      name     city
# a   Akhil       NY
# c  Charan  chicago

# %%
print(df.loc["a":"c"])
print(df.iloc[0:2])
# Out:
#      name  age     city
# a   Akhil   25       NY
# b   Bobby   30       LS
# c  Charan   35  chicago
#     name  age city
# a  Akhil   25   NY
# b  Bobby   30   LS

# %% [markdown]
# 11-02-2026

# %%
print(df.loc[df["age"]>])

# %%
import pandas as pd
df=pd.DataFrame({
    "name":["Akhil","Bobby","Charan"],
    "age":[25,30,35],
    "city":["NY","LS","chicago"],
},index=["a","b","c"])
print(df)
print()
print(df.iloc[1])
# Out:
#      name  age     city
# a   Akhil   25       NY
# b   Bobby   30       LS
# c  Charan   35  chicago
#
# name    Bobby
# age        30
# city       LS
# Name: b, dtype: object

# %%
print(df.iloc[1])
# Out:
# name    Bobby
# age        30
# city       LS
# Name: b, dtype: object

# %%
print(df.iloc[[0,2],[1,2]])
# Out:
#    age     city
# a   25       NY
# c   35  chicago

# %%
import pandas as pd
df=pd.DataFrame({
    "name":["Akhil","Bobby","Charan"],
    "age":[25,30,35],
    "city":["NY","LS","chicago"],
},index=["a","b","c"])
print(df)
print()
df.iloc[[0:2]]

# %%
df["name"]
# Out:
# a     Akhil
# b     Bobby
# c    Charan
# Name: name, dtype: object

# %%
df[["name","age"]]
# Out:
#      name  age
# a   Akhil   25
# b   Bobby   30
# c  Charan   35

# %%
import pandas as pd
data={
    "Farm":["Farm A","Farm B","Farm C","Farm D"],
    "Crop":["Wheat","Rice","Wheat","Maize"],
    "Area_hectares":[10,15,8,12],
    "Production_tons":[30,60,24,36]
}
df=pd.DataFrame(data)
print(df)
# Out:
#      Farm   Crop  Area_hectares  Production_tons
# 0  Farm A  Wheat             10               30
# 1  Farm B   Rice             15               60
# 2  Farm C  Wheat              8               24
# 3  Farm D  Maize             12               36

# %%
df.tail(2)
# Out:
#      Farm   Crop  Area_hectares  Production_tons
# 2  Farm C  Wheat              8               24
# 3  Farm D  Maize             12               36

# %%
df.head(5)
# Out:
#      Farm   Crop  Area_hectares  Production_tons
# 0  Farm A  Wheat             10               30
# 1  Farm B   Rice             15               60
# 2  Farm C  Wheat              8               24
# 3  Farm D  Maize             12               36

# %%
import pandas as pd
data={
    "Farm":["Farm A","Farm B","Farm C","Farm D"],
    "Crop":["Wheat","Rice","Wheat","Maize"],
    "Area_hectares":[10,15,8,12],
    "Production_tons":[30,60,24,36]
}
df=pd.DataFrame(data)

df["yield_ton_per_hectare"]=df["Production_tons"]/df["Area_hectares"]
print(df)
# Out:
#      Farm   Crop  Area_hectares  Production_tons  yield_ton_per_hectare
# 0  Farm A  Wheat             10               30                    3.0
# 1  Farm B   Rice             15               60                    4.0
# 2  Farm C  Wheat              8               24                    3.0
# 3  Farm D  Maize             12               36                    3.0

# %%
df.iloc[[1,3]]
# Out:
#      Farm   Crop  Area_hectares  Production_tons
# 1  Farm B   Rice             15               60
# 3  Farm D  Maize             12               36

# %%
df.iloc[[1,3][0:3]]
# Out:
#      Farm   Crop  Area_hectares  Production_tons
# 1  Farm B   Rice             15               60
# 3  Farm D  Maize             12               36

# %%
print([df["Crop"]=="Wheat"])
print()
wheat_farms=df[df["Crop"]=="Wheat"]
print(wheat_farms)
# Out:
# [0     True
# 1    False
# 2     True
# 3    False
# Name: Crop, dtype: bool]
#
#      Farm   Crop  Area_hectares  Production_tons
# 0  Farm A  Wheat             10               30
# 2  Farm C  Wheat              8               24

# %%
#sort farms by highest production
sorted_df=df.sort_values(by="production_tons")

# %%
#groupby operation - average yield per crop
avg_yield=df.groupby("Crop")["yield_ton_per_hectare"].mean()
print(avg_yield)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-831168116.py in <cell line: 0>()
#       1 #groupby operation - average yield per crop
# ----> 2 avg_yield=df.groupby("Crop")["yield_ton_per_hectare"].mean()
#       3 print(avg_yield)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1949                 "Use a list instead."
#    1950             )
# -> 1951         return super().__getitem__(key)
#    1952
#    1953     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     242         else:
#     243             if key not in self.obj:
# --> 244                 raise KeyError(f"Column not found: {key}")
#     245             ndim = self.obj[key].ndim
#     246             return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: yield_ton_per_hectare'
